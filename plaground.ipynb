# %%
from main import fetch_profiles
import json

try:
    result = fetch_profiles()
    print(json.dumps(result, indent=2))
except Exception as e:
    print(f"Error: {e}")
# Out:
# {
#   "data": {
#     "searchProvidersChildCare": {
#       "sourceType": "PN",
#       "searchProvidersConnection": {
#         "pageInfo": {
#           "hasNextPage": true,
#           "endCursor": "U2VlZD0wLEluZGV4PTIwLFBhZ2VTY3JvbGxJZD0yNWZjNDJkNjgxMzA0NDRhOWVkZTY4OTcwNmM3YmY0NA==",
#           "__typename": "PageInfo"
#         },
#         "totalHits": 106,
#         "edges": [
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/20/26458920_7zb8XhI3cdPEKuMaLovnvXVcKmiAvF00",
#                 "displayName": "Tamisha W.",
#                 "firstName": "Tamisha",
#                 "lastName": "W",
#                 "address": {
#                   "city": "Hillside",
#                   "state": "NJ",
#                   "zip": "07205",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 81,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 46,
#                   "averageRatings": [
#                     {
#                       "type": "OVERALL",
#                       "value": 4.9782609939575195,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "DEPENDABILITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "PUNCTUALITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "RELIABLE_TRANSPORTATION",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     }
#                   ],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "18642323",
#                   "bio": {
#                     "experienceSummary": "Professional individual who has years of experience caring for children. I have a 29 and 21-year-old of my own and have been caring for others for quite sometime. I am a certified substitute teacher in the state of NJ and am fingerprinted by NJ state, certified in adult and child CPR. I love children and will care for your child as if they were my own. I'm a very reliable, organized, creative and well planned out care provider. I currently tutor and mentor children in my spare time and truly love what I do.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "29",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "32",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 3,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "35",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 4,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "15",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "50",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": {
#                 "description": {
#                   "displayText": "",
#                   "originalText": "Very pleased with Tamisha, she was very responsive, punctual and she had no trouble winning my son over and stepping into the care role. This was my first time using Care.com and looking for a sitter for my son and I got very lucky with Tamisha!",
#                   "__typename": "ReviewInfoText"
#                 },
#                 "reviewer": {
#                   "publicMemberInfo": {
#                     "firstName": "Isabel",
#                     "lastInitial": "C",
#                     "imageURL": null,
#                     "__typename": "PublicMemberInfo"
#                   },
#                   "__typename": "ReviewInfoReviewer"
#                 },
#                 "__typename": "ReviewInfo"
#               },
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/81/25774281_6AE5PC3PsAo8g7uFEnmBn4KMgzVTf010",
#                 "displayName": "Tiffany W.",
#                 "firstName": "Tiffany",
#                 "lastName": "W",
#                 "address": {
#                   "city": "Plainfield",
#                   "state": "NJ",
#                   "zip": "07060",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "SENIOR_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "PREMIUM"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 5,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 7,
#                   "averageRatings": [
#                     {
#                       "type": "DEPENDABILITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "PUNCTUALITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "OVERALL",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     }
#                   ],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "14423292",
#                   "bio": {
#                     "experienceSummary": "I really enjoy working with elderly patients and Children. I have over 10 years experience in being a Caregiver. from Children to Elderly. I truly do enjoy what I do. I am know for being Caring, understanding, helpful, hardworking, and so much more. \n\nRecommendation letters available upon request",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "29",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "10",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "15",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": {
#                 "description": {
#                   "displayText": "We will miss Tiffany as she became part of our family.  She was punctual and professional and she is an asset to anyone who has her assistance.",
#                   "originalText": "We will miss Tiffany as she became part of our family.  She was punctual and professional and she is an asset to anyone who has her assistance.",
#                   "__typename": "ReviewInfoText"
#                 },
#                 "reviewer": {
#                   "publicMemberInfo": {
#                     "firstName": "Melanie",
#                     "lastInitial": "H",
#                     "imageURL": null,
#                     "__typename": "PublicMemberInfo"
#                   },
#                   "__typename": "ReviewInfoReviewer"
#                 },
#                 "__typename": "ReviewInfo"
#               },
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/83/46472683_ss5ii6rCVl3Cs0NIOqkWzvK36tOhwO300",
#                 "displayName": "Jessica L.",
#                 "firstName": "Jessica",
#                 "lastName": "L",
#                 "address": {
#                   "city": "Elizabeth",
#                   "state": "NJ",
#                   "zip": "07202",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "PREMIUM",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 0,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 0,
#                   "averageRatings": [],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "29907325",
#                   "bio": {
#                     "experienceSummary": "I am a calm, patient, caring, organized, hard-working, and responsible individual. I have 10 years of child-care experience. Recently, I was a full-time nanny to a family with 3 kids, ages 3, 7 & 9. Prior, I cared for 2 girls from when the youngest was 4 months up to when she was 9 years old as a part-time live-in nanny. I enjoy photography, travel, reading, cooking, and hiking. I attended college in NYC and loved exploring the city and going to parks. \nI am currently looking for a job with 30-40 hours.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "29",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "30",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "30",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": null,
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/28/46781828_cfgQ1Ri8kR5h1siU8COozeAPndIAi010",
#                 "displayName": "Autumn H.",
#                 "firstName": "Autumn",
#                 "lastName": "H",
#                 "address": {
#                   "city": "Scotch Plains",
#                   "state": "NJ",
#                   "zip": "07076",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 4,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 23,
#                   "averageRatings": [
#                     {
#                       "type": "OVERALL",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "ACCURATE_CALENDAR",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "DEPENDABILITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "PUNCTUALITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "RELIABLE_TRANSPORTATION",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     }
#                   ],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "616867",
#                   "bio": {
#                     "experienceSummary": "Please read my profile before contacting me. Serious inquires only. $30 hour and up \nCurrently seeking :\n* Pet sitting in your home. \n* Occasional sitting weekend/overnights\n*Travel Nanny w Passport and local events (weddings etc.)\n\nMy Early Educator as a teaching assistant, began 2007 to 2012 ages 2 to 5 y. o\nPromoted to Lead Teacher of 30-36-month-old's. From 2012 until 2019\nEvening Nanny to family of 4 children, 3 pets 2012 current\nCurrently at a Goddard School in Infant room since March2019\nCertified Children's yoga instructor 2014 current\n\nI can bring many positive, creative, joyful, and helpful influences to you, your home environment, and children. I am very open-minded, diverse and a quick learner. I have a bright and loving spirit and enjoy teaching young children through play while maintaining a safe and secure environment for them. I tend to be a neat freak and enjoy coming up with fun ways to help children pick up after themselves.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "35",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "35",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "40",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 3,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "40",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 4,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "35",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "35",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": {
#                 "description": {
#                   "displayText": "Autumn watched my 6 months old for 3 days for 4 hours each day. She is by far the best sitter I have ever met. I would hire her again. She is very accommodating. She was great with the baby, didn't have any trouble putting her down for naps, spent time engaging the baby with books and toys. So loving. Highly recommend.",
#                   "originalText": "Autumn watched my 6 months old for 3 days for 4 hours each day. She is by far the best sitter I have ever met. I would hire her again. She is very accommodating. She was great with the baby, didn't have any trouble putting her down for naps, spent time engaging the baby with books and toys. So loving. Highly recommend.",
#                   "__typename": "ReviewInfoText"
#                 },
#                 "reviewer": {
#                   "publicMemberInfo": {
#                     "firstName": "Adriana",
#                     "lastInitial": "I",
#                     "imageURL": "https://www.care.com/s/d/aws/photo/135X135/12/42037212_Z0igy4CZgTiXLpzQ9R6q7JSqy1zk010",
#                     "__typename": "PublicMemberInfo"
#                   },
#                   "__typename": "ReviewInfoReviewer"
#                 },
#                 "__typename": "ReviewInfo"
#               },
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/40/44326940_Uxf7plaSUGnq1Vd6QpAfawjTeCkRB00",
#                 "displayName": "Emma M.",
#                 "firstName": "Emma",
#                 "lastName": "M",
#                 "address": {
#                   "city": "Rahway",
#                   "state": "NJ",
#                   "zip": "07065",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK"
#               ],
#               "yearsOfExperience": 7,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 1,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 1,
#                   "averageRatings": [
#                     {
#                       "type": "PUNCTUALITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "OVERALL",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "DEPENDABILITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     }
#                   ],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "26332563",
#                   "bio": {
#                     "experienceSummary": "Hello, I am a 30-year-old based here in Union County (Rahway). I have years of experience in childcare, my most recent position being a co-teacher of a Reggio style based classroom in a private school in Mountainside; previously, I worked as a 'guide' at a private school called Acton Academy. Years of experience in alternative learning has given me the opportunity to focus on child-led collaborative learning and play. My background includes teaching elementary aged children, art facilitation, after school programs, and social work. Some skill sets that I will bring to this position is my acute responsibly, my love for working with children, my patience and kind-but-firm nature, willingness to help with homework, housework and cooking, my art age-appropriate activities I bring with me; as well as this, I own a vehicle with a clean record, Please get in contact with me anytime, am very quick to respond!",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "29",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "32",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 3,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "20",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "25",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": {
#                 "description": {
#                   "displayText": "Very friendly, great with kids, trustworthy.",
#                   "originalText": "Very friendly, great with kids, trustworthy.",
#                   "__typename": "ReviewInfoText"
#                 },
#                 "reviewer": {
#                   "publicMemberInfo": {
#                     "firstName": "Dana",
#                     "lastInitial": "A",
#                     "imageURL": "https://www.care.com/s/d/aws/photo/135X135/90/39566490_GUlwXdrXTht1wWA2z90qvmiAARSa00",
#                     "__typename": "PublicMemberInfo"
#                   },
#                   "__typename": "ReviewInfoReviewer"
#                 },
#                 "__typename": "ReviewInfo"
#               },
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/61/46846161_1CeJOgBuz5jdRNxtnmLy92nANdPHu010",
#                 "displayName": "Angela T.",
#                 "firstName": "Angela",
#                 "lastName": "T",
#                 "address": {
#                   "city": "Roselle",
#                   "state": "NJ",
#                   "zip": "07203",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 5,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 0,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 0,
#                   "averageRatings": [],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "35665146",
#                   "bio": {
#                     "experienceSummary": "I'm passionate about supporting families and helping children grow and learn. I have 5 years of experience as a childcare provider and am comfortable caring for children of all ages. I'm patient, calm, and creative, and I love to play outdoor sports, board games, and educational games. I'm also comfortable enforcing household rules and communicating with parents about their children's day or any issues that arise. I have my First Aid Training and CPR Training, and I'm willing to help with cooking, meal preparation, travel, and swimming supervision. I'm looking forward to providing your family with reliable, high-quality childcare.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "29",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "22",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "22",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": null,
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/0/46182200_HMxlaMf3yBVvb7FEnZUFHj4UA7k010",
#                 "displayName": "Talia L.",
#                 "firstName": "Talia",
#                 "lastName": "L",
#                 "address": {
#                   "city": "Union",
#                   "state": "NJ",
#                   "zip": "07083",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "PREMIUM",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 7,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 0,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 0,
#                   "averageRatings": [],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "34223728",
#                   "bio": {
#                     "experienceSummary": "Hello my name is Talia. I am CPR certified. I have been working with children of all ages for the last 6 years. I speak Spanish.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "25",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "30",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "35",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 3,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "40",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 4,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "15",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "25",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": null,
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/92/46922192_NrAYXRhTdu29C3sCUsrGKRNdfupa00",
#                 "displayName": "Lola P.",
#                 "firstName": "Lola",
#                 "lastName": "P",
#                 "address": {
#                   "city": "Bayonne",
#                   "state": "NJ",
#                   "zip": "07002",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "SENIOR_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 0,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 0,
#                   "averageRatings": [],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "31196971",
#                   "bio": {
#                     "experienceSummary": "As a childcare provider, I enjoy sharing my love of the outdoors and creativity/art with kids. I have over 10 years of experience including my own two babes whom are 11&5 yrs of age. I think it's important to provide children with a fun, fulfilling and enriched environment. I am an enthusiastic and responsible person and look forward to meeting you and your kids!",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "27",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "16",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "21",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": null,
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/93/21031893_ZeDblyr4di5ACl3eomW8BiPoSE4av010",
#                 "displayName": "Kathy W.",
#                 "firstName": "Kathy",
#                 "lastName": "W",
#                 "address": {
#                   "city": "Woodbridge",
#                   "state": "NJ",
#                   "zip": "07095",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 10,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 11,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 2,
#                   "averageRatings": [
#                     {
#                       "type": "OVERALL",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "DEPENDABILITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "PUNCTUALITY",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     },
#                     {
#                       "type": "RELIABLE_TRANSPORTATION",
#                       "value": 5,
#                       "__typename": "ReviewInfoRating"
#                     }
#                   ],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "1672979",
#                   "bio": {
#                     "experienceSummary": "I have over 20 years of experience working with infants and children! I have a great passion for working with, and caring for them! They play a major part in my life! I have four children, which includes twins, and five grandhildren. Most of my free time is spent with them",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "20",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     },
#                     {
#                       "hourlyRate": {
#                         "amount": "25",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 2,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "20",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "25",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": {
#                 "description": {
#                   "displayText": "",
#                   "originalText": "I am a FTM. Kathy helped guide me on how to take care of my 4 month old while also caring for him during the summer. She is kind, caring, and knows her stuff! She's knowledgeable and flexible. I enjoyed having Kathy care for my son. I would hire her if I needed child care again. ",
#                   "__typename": "ReviewInfoText"
#                 },
#                 "reviewer": {
#                   "publicMemberInfo": {
#                     "firstName": "Nancy",
#                     "lastInitial": "N",
#                     "imageURL": null,
#                     "__typename": "PublicMemberInfo"
#                   },
#                   "__typename": "ReviewInfoReviewer"
#                 },
#                 "__typename": "ReviewInfo"
#               },
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           },
#           {
#             "node": {
#               "member": {
#                 "id": "",
#                 "legacyId": "",
#                 "imageURL": "https://www.care.com/s/d/aws/photo/135X135/43/46783043_fkvG1rXpdRqEViRwTfhhzaYuWItPgm010",
#                 "displayName": "Nathalia N.",
#                 "firstName": "Nathalia",
#                 "lastName": "N",
#                 "address": {
#                   "city": "Kenilworth",
#                   "state": "NJ",
#                   "zip": "07033",
#                   "__typename": "Address"
#                 },
#                 "primaryService": "CHILD_CARE",
#                 "__typename": "Member"
#               },
#               "hasCareCheck": true,
#               "badges": [
#                 "BACKGROUND_CHECK",
#                 "PREMIUM",
#                 "VACCINATED"
#               ],
#               "yearsOfExperience": 3,
#               "profileDataSource": "bravo",
#               "hiredByCounts": {
#                 "locality": null,
#                 "__typename": "CaregiverHiredByCounts"
#               },
#               "hiredTimes": 0,
#               "revieweeMetrics": {
#                 "metrics": {
#                   "totalReviews": 0,
#                   "averageRatings": [],
#                   "__typename": "RevieweeMetrics"
#                 },
#                 "__typename": "RevieweeMetricsPayload"
#               },
#               "profiles": {
#                 "commonCaregiverProfile": {
#                   "id": "33248681",
#                   "bio": {
#                     "experienceSummary": "I'm a 23-year-old pedagogy student with a passion for teaching. I started working as a teacher in Brazil at 18 and have loved every moment of it. I've also been a talented babysitter for three years, and I truly enjoy being around children. I care for them with love, patience, and respect, always keeping things easygoing and making learning fun and engaging for everyone.",
#                     "__typename": "Bio"
#                   },
#                   "__typename": "CommonCaregiverProfile"
#                 },
#                 "childCareCaregiverProfile": {
#                   "rates": [
#                     {
#                       "hourlyRate": {
#                         "amount": "26",
#                         "__typename": "Money"
#                       },
#                       "numberOfChildren": 1,
#                       "__typename": "OneTimeChildCareRates"
#                     }
#                   ],
#                   "recurringRate": {
#                     "hourlyRateFrom": {
#                       "amount": "22",
#                       "__typename": "Money"
#                     },
#                     "hourlyRateTo": {
#                       "amount": "22",
#                       "__typename": "Money"
#                     },
#                     "__typename": "PayRange"
#                   },
#                   "__typename": "ChildCareCaregiverProfile"
#                 },
#                 "petCareCaregiverProfile": null,
#                 "houseKeepingCaregiverProfile": null,
#                 "tutoringCaregiverProfile": null,
#                 "seniorCareCaregiverProfile": null,
#                 "__typename": "CaregiverProfiles"
#               },
#               "featuredReview": null,
#               "isFavorite": false,
#               "__typename": "Caregiver"
#             },
#             "__typename": "SearchProvidersEdge"
#           }
#         ],
#         "__typename": "SearchProvidersConnection"
#       },
#       "__typename": "SearchProvidersSuccess"
#     }
#   }
# }
