# %%
from Scrapers.Scraper import run_scraper
run_scraper()
# Out:
# [2025-05-07 19:53:29] INFO - Log file initialized at: raw_data\malt_fr\développeur_python\en_télétravail\scrape_malt_développeur_python.log
# [2025-05-07 19:53:29] INFO - MaltScraper initialized for query 'développeur python' at 'En télétravail (France)'
# [2025-05-07 19:53:29] INFO - Starting Malt.fr scraping run ID: adb97b5b-5d0e-4949-a07b-427e46010d4d
# Query: 'développeur python', Location: 'En télétravail (France)'
# Price Config: Start 125, Step 50, Open Range From 800
# Max Pages per Range: 5
# [2025-05-07 19:53:29] INFO - Generated 15 price ranges to scrape.
# [2025-05-07 19:53:29] INFO - --- Processing Price Range 1/15: [125 - 174] ---
# [2025-05-07 19:53:29] INFO - Fetching data for price range [125, 174] EUR...
# [2025-05-07 19:53:29] INFO -   - Page 1: 24 profiles. Saved to raw_data\malt_fr\développeur_python\en_télétravail\range_125_174\page_1.json
# ...
