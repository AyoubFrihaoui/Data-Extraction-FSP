# %%
from Scrapers.Scraper import MaltScraper
scraper = MaltScraper(
    query_term="developpeur",   # Example Query
    location_name="En télétravail (France)", # Example Location
    remote_allowed=True,
    initial_min_price=125,              # Example Price Start
    price_step=50,                     # Example Price Step
    final_min_price_for_open_range=800, # Example Final Range Start
    max_pages_per_range=500,             # Limit pages for testing/politeness
    num_workers=8                      # Adjust based on testing and network
    # cookie=MALT_COOKIE,               # Loaded by default from config.py
    # xsrf_token=MALT_XSRF_TOKEN        # Loaded by default from config.py
)
# --- Run the Scraper ---
scraper.run()
print("\n--- Scraping script finished ---")
# Out:
# [2025-05-12 15:44:36] INFO - Log file initialized at: raw_data\malt_fr\developpeur\en_télétravail\scrape_malt_developpeur.log
# [2025-05-12 15:44:36] INFO - MaltScraper initialized for query 'developpeur' at 'En télétravail (France)' with 8 workers.
# [2025-05-12 15:44:36] INFO - Starting Malt.fr scraping run ID: 4ff409a2-be3d-447f-8886-f7a4ac129fda
# Query: 'developpeur', Location: 'En télétravail (France)'
# Price Config: Start 125, Step 50, Open Range From 800
# Max Pages per Range: 500, Workers per Range: 8
# [2025-05-12 15:44:36] INFO - Generated 15 price ranges to scrape.
# [2025-05-12 15:44:36] INFO - --- Processing Price Range 1/15: [125_174] ---
# [2025-05-12 15:44:36] INFO - Fetching data for price range [125_174] using 8 workers...
# [2025-05-12 15:44:37] INFO -   - Worker finished page 4: Found 24 profiles.
# [2025-05-12 15:44:37] INFO -   - Worker finished page 3: Found 24 profiles.
# [2025-05-12 15:44:37] INFO -   - Worker finished page 6: Found 24 profiles.
# ...

# %%
from Scrapers.ProfilesScraper import scrape_html_profiles

scrape_html_profiles()
# Out:
# Using base input directory for JSON files: d:\Data Extraction FSP\Malt-fr\raw_data\malt_fr
# Starting overall HTML Profile Scraping Process. Run ID: 3244c000-0d31-443f-a6e5-b3fe380777fb
# Scanning base input directory: raw_data\malt_fr
# Found 1 query directories to process: ['developpeur']
#   Processing query 'developpeur': Found 1 location(s).
# [2025-05-21 01:08:50] INFO [ProfilesScraper:201] - HTML Profile Scraper logging initialized for developpeur/en_télétravail. Log file: raw_data\malt_fr\developpeur\en_télétravail\scrape_html_profiles_developpeur_en_télétravail.log
# [2025-05-21 01:08:50] INFO [ProfilesScraper:408] - --- Starting HTML Profile Scraping for: developpeur / en_télétravail ---
# [2025-05-21 01:08:50] INFO [ProfilesScraper:411] - Run ID for this HTML scrape: 3244c000-0d31-443f-a6e5-b3fe380777fb
# ...
