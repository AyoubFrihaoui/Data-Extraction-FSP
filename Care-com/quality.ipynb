# %%
from etl.data_quality_check import run_quality

run_quality()
# Out:
# 2025-04-11 16:17:48,784 - INFO - [testcopy2.py:808] - Starting Data Quality Check Script for ALL ZIPS in USA
# 2025-04-11 16:17:48,785 - INFO - [testcopy2.py:821] - Scanning for zip code directories in: raw_data\USA
# 2025-04-11 16:17:48,786 - INFO - [testcopy2.py:828] - --- Processing Zip Code: 07008 ---
# 2025-04-11 16:17:48,788 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\07008\all_profiles
# 2025-04-11 16:18:05,580 - INFO - [testcopy2.py:73] - Scanned 3870 files. Found 1935 valid JSON files in raw_data\USA\07008\all_profiles.
# 2025-04-11 16:18:05,582 - INFO - [testcopy2.py:837] - Loaded 1935 profiles for zip 07008.
# 2025-04-11 16:18:05,583 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\07008\reviews\CHILD_CARE
# 2025-04-11 16:18:10,807 - INFO - [testcopy2.py:73] - Scanned 3904 files. Found 1952 valid JSON files in raw_data\USA\07008\reviews\CHILD_CARE.
# 2025-04-11 16:18:10,808 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\07008\reviews\HOUSEKEEPING
# 2025-04-11 16:18:13,960 - INFO - [testcopy2.py:73] - Scanned 3892 files. Found 1946 valid JSON files in raw_data\USA\07008\reviews\HOUSEKEEPING.
# 2025-04-11 16:18:13,962 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\07008\reviews\SENIOR_CARE
# 2025-04-11 16:18:17,609 - INFO - [testcopy2.py:73] - Scanned 3886 files. Found 1943 valid JSON files in raw_data\USA\07008\reviews\SENIOR_CARE.
# 2025-04-11 16:18:17,610 - INFO - [testcopy2.py:828] - --- Processing Zip Code: 10002 ---
# 2025-04-11 16:18:17,611 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\10002\all_profiles
# 2025-04-11 16:19:32,258 - INFO - [testcopy2.py:73] - Scanned 16628 files. Found 8314 valid JSON files in raw_data\USA\10002\all_profiles.
# 2025-04-11 16:19:32,260 - INFO - [testcopy2.py:837] - Loaded 8314 profiles for zip 10002.
# 2025-04-11 16:19:32,261 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\10002\reviews\CHILD_CARE
# 2025-04-11 16:19:56,647 - INFO - [testcopy2.py:73] - Scanned 16804 files. Found 8402 valid JSON files in raw_data\USA\10002\reviews\CHILD_CARE.
# 2025-04-11 16:19:56,649 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\10002\reviews\HOUSEKEEPING
# 2025-04-11 16:20:01,890 - INFO - [testcopy2.py:73] - Scanned 16692 files. Found 8346 valid JSON files in raw_data\USA\10002\reviews\HOUSEKEEPING.
# 2025-04-11 16:20:01,891 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\10002\reviews\SENIOR_CARE
# 2025-04-11 16:20:03,781 - INFO - [testcopy2.py:73] - Scanned 16666 files. Found 8333 valid JSON files in raw_data\USA\10002\reviews\SENIOR_CARE.
# 2025-04-11 16:20:03,783 - INFO - [testcopy2.py:828] - --- Processing Zip Code: 30306 ---
# 2025-04-11 16:20:03,784 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\30306\all_profiles
# 2025-04-11 16:20:05,082 - INFO - [testcopy2.py:73] - Scanned 3760 files. Found 1880 valid JSON files in raw_data\USA\30306\all_profiles.
# 2025-04-11 16:20:05,083 - INFO - [testcopy2.py:837] - Loaded 1880 profiles for zip 30306.
# 2025-04-11 16:20:05,084 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\30306\reviews\CHILD_CARE
# 2025-04-11 16:20:05,655 - INFO - [testcopy2.py:73] - Scanned 3848 files. Found 1924 valid JSON files in raw_data\USA\30306\reviews\CHILD_CARE.
# 2025-04-11 16:20:05,657 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\30306\reviews\HOUSEKEEPING
# 2025-04-11 16:20:06,214 - INFO - [testcopy2.py:73] - Scanned 3764 files. Found 1882 valid JSON files in raw_data\USA\30306\reviews\HOUSEKEEPING.
# 2025-04-11 16:20:06,215 - INFO - [testcopy2.py:63] - Scanning for JSON files in: raw_data\USA\30306\reviews\SENIOR_CARE
# 2025-04-11 16:20:06,705 - INFO - [testcopy2.py:73] - Scanned 3772 files. Found 1886 valid JSON files in raw_data\USA\30306\reviews\SENIOR_CARE.
# 2025-04-11 16:20:06,707 - INFO - [testcopy2.py:849] - Finished scanning 3 potential zip code directories.
# 2025-04-11 16:20:06,709 - INFO - [testcopy2.py:857] - --- Processing ALL 12129 Profile Items ---
# 2025-04-11 16:20:19,137 - INFO - [testcopy2.py:375] - Created DataFrame for all_main_profiles with 12129 records and 40 columns.
# 2025-04-11 16:20:19,148 - INFO - [testcopy2.py:863] - DEDUPLICATION STEP FOR PROFILES...
# 2025-04-11 16:20:19,206 - WARNING - [testcopy2.py:875] - Removed 236 duplicate profiles based on 'profile_id'. Kept first occurrence.
# 2025-04-11 16:20:19,207 - INFO - [testcopy2.py:455] - --- Running Quality Checks for main_profiles (11893 rows) ---
# 2025-04-11 16:20:19,209 - INFO - [testcopy2.py:458] - Data types PRE-validation for main_profiles:
# string                 26
# boolean                 8
# Int64                   4
# object                  1
# datetime64[ns, UTC]     1
# Name: count, dtype: int64
# 2025-04-11 16:20:19,307 - INFO - [testcopy2.py:463] - Schema validation PASSED for main_profiles.
# 2025-04-11 16:20:20,971 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_main_profiles.csv
# 2025-04-11 16:20:22,650 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\main_profiles_processed.csv
# 2025-04-11 16:20:22,651 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for main_profiles ---
# 2025-04-11 16:20:22,657 - INFO - [testcopy2.py:883] - Extracting and flattening nested profiles from aggregated main profiles...
# 2025-04-11 16:20:25,431 - INFO - [testcopy2.py:896] - Processing aggregated nested profiles by type...
# 2025-04-11 16:20:25,432 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_commonCaregiverProfile ---
# 2025-04-11 16:20:25,463 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:25,472 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_commonCaregiverProfile (11893 rows) ---
# 2025-04-11 16:20:25,474 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_commonCaregiverProfile:
# string    6
# Int64     1
# Name: count, dtype: int64
# 2025-04-11 16:20:25,511 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_commonCaregiverProfile.
# 2025-04-11 16:20:25,580 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_commonCaregiverProfile.csv
# 2025-04-11 16:20:25,633 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_commonCaregiverProfile_processed.csv
# 2025-04-11 16:20:25,634 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_commonCaregiverProfile ---
# 2025-04-11 16:20:25,635 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_commonCaregiverProfile ---
# 2025-04-11 16:20:25,636 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_seniorCareCaregiverProfile ---
# 2025-04-11 16:20:25,685 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:25,701 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_seniorCareCaregiverProfile (4655 rows) ---
# 2025-04-11 16:20:25,707 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_seniorCareCaregiverProfile:
# string    14
# object     5
# Int64      3
# Name: count, dtype: int64
# 2025-04-11 16:20:25,758 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_seniorCareCaregiverProfile.
# 2025-04-11 16:20:25,887 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_seniorCareCaregiverProfile.csv
# 2025-04-11 16:20:26,019 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_seniorCareCaregiverProfile_processed.csv
# 2025-04-11 16:20:26,020 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_seniorCareCaregiverProfile ---
# 2025-04-11 16:20:26,021 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_seniorCareCaregiverProfile ---
# 2025-04-11 16:20:26,021 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_childCareCaregiverProfile ---
# 2025-04-11 16:20:26,102 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:26,119 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_childCareCaregiverProfile (9264 rows) ---
# 2025-04-11 16:20:26,120 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_childCareCaregiverProfile:
# string    16
# object     9
# Int64      3
# Name: count, dtype: int64
# 2025-04-11 16:20:26,157 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_childCareCaregiverProfile.
# 2025-04-11 16:20:26,841 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_childCareCaregiverProfile.csv
# 2025-04-11 16:20:27,237 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_childCareCaregiverProfile_processed.csv
# 2025-04-11 16:20:27,238 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_childCareCaregiverProfile ---
# 2025-04-11 16:20:27,240 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_childCareCaregiverProfile ---
# 2025-04-11 16:20:27,241 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_petCareCaregiverProfile ---
# 2025-04-11 16:20:27,279 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:27,286 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_petCareCaregiverProfile (3242 rows) ---
# 2025-04-11 16:20:27,289 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_petCareCaregiverProfile:
# string    16
# object     5
# Int64      2
# Name: count, dtype: int64
# 2025-04-11 16:20:27,313 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_petCareCaregiverProfile.
# 2025-04-11 16:20:27,487 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_petCareCaregiverProfile.csv
# 2025-04-11 16:20:27,711 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_petCareCaregiverProfile_processed.csv
# 2025-04-11 16:20:27,712 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_petCareCaregiverProfile ---
# 2025-04-11 16:20:27,713 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_petCareCaregiverProfile ---
# 2025-04-11 16:20:27,715 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_houseKeepingCaregiverProfile ---
# 2025-04-11 16:20:27,743 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:27,749 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_houseKeepingCaregiverProfile (3356 rows) ---
# 2025-04-11 16:20:27,751 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_houseKeepingCaregiverProfile:
# string    15
# object     6
# Int64      1
# Name: count, dtype: int64
# 2025-04-11 16:20:27,774 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_houseKeepingCaregiverProfile.
# 2025-04-11 16:20:27,853 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_houseKeepingCaregiverProfile.csv
# 2025-04-11 16:20:27,942 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_houseKeepingCaregiverProfile_processed.csv
# 2025-04-11 16:20:27,944 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_houseKeepingCaregiverProfile ---
# 2025-04-11 16:20:27,945 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_houseKeepingCaregiverProfile ---
# 2025-04-11 16:20:27,945 - INFO - [testcopy2.py:899] - --- Creating DataFrame and running checks for aggregated: nested_tutoringCaregiverProfile ---
# 2025-04-11 16:20:27,961 - INFO - [testcopy2.py:905] - DEDUPLICATION STEP FOR NESTED PROFILES...
# 2025-04-11 16:20:27,965 - INFO - [testcopy2.py:455] - --- Running Quality Checks for nested_tutoringCaregiverProfile (1391 rows) ---
# 2025-04-11 16:20:27,966 - INFO - [testcopy2.py:458] - Data types PRE-validation for nested_tutoringCaregiverProfile:
# string    16
# object     5
# Int64      1
# Name: count, dtype: int64
# 2025-04-11 16:20:27,980 - INFO - [testcopy2.py:463] - Schema validation PASSED for nested_tutoringCaregiverProfile.
# 2025-04-11 16:20:28,019 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_nested_tutoringCaregiverProfile.csv
# 2025-04-11 16:20:28,067 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\nested_tutoringCaregiverProfile_processed.csv
# 2025-04-11 16:20:28,068 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for nested_tutoringCaregiverProfile ---
# 2025-04-11 16:20:28,068 - INFO - [testcopy2.py:915] - --- Finished checks for aggregated: nested_tutoringCaregiverProfile ---
# 2025-04-11 16:20:28,069 - INFO - [testcopy2.py:923] - --- Processing ALL 36614 Review Items ---
# 2025-04-11 16:20:46,228 - INFO - [testcopy2.py:403] - Created DataFrame for reviews with 13387 records and 25 columns.
# 2025-04-11 16:20:46,236 - INFO - [testcopy2.py:929] - DEDUPLICATION STEP FOR REVIEWS...
# 2025-04-11 16:20:46,274 - WARNING - [testcopy2.py:941] - Removed 331 duplicate reviews based on 'review_id'. Kept first occurrence.
# 2025-04-11 16:20:46,275 - INFO - [testcopy2.py:455] - --- Running Quality Checks for reviews (13056 rows) ---
# 2025-04-11 16:20:46,278 - INFO - [testcopy2.py:458] - Data types PRE-validation for reviews:
# string                 21
# datetime64[ns, UTC]     2
# datetime64[ns]          1
# boolean                 1
# Name: count, dtype: int64
# 2025-04-11 16:20:46,348 - INFO - [testcopy2.py:463] - Schema validation PASSED for reviews.
# 2025-04-11 16:20:46,487 - INFO - [testcopy2.py:527] - Quality report saved to: preprocessed_data\USA\quality_report_reviews.csv
# 2025-04-11 16:20:46,873 - INFO - [testcopy2.py:532] - Processed data saved to: preprocessed_data\USA\reviews_processed.csv
# 2025-04-11 16:20:46,874 - INFO - [testcopy2.py:540] - --- Finished Quality Checks for reviews ---
# 2025-04-11 16:20:46,879 - INFO - [testcopy2.py:950] - --- Proposed Data Model ---
# 2025-04-11 16:20:46,879 - INFO - [testcopy2.py:951] - --- Data Quality Check Script Finished for USA ---
#     Proposed Relational Data Model (Hybrid Flattening):
#     ----------------------------------------------------
#     NOTE: NestedServiceProfiles columns contain dynamically flattened fields
#           from qualities, services, etc. prefixed by sub-profile type.
#           JSON columns require further parsing/normalization in ETL/DB.
#
#     1. Profiles (Main Caregiver Information)
#        - profile_id (PK, VARCHAR) - From member.id
#        - source_filename (VARCHAR)
#        - member_firstName (VARCHAR, Nullable)
#        - member_lastName (VARCHAR, Nullable)
#        - member_gender (VARCHAR, Nullable)
#        - member_displayName (VARCHAR, Nullable)
#        - member_email (VARCHAR, Nullable)
#        - member_primaryService (VARCHAR, Nullable)
#        - member_hiResImageURL (VARCHAR, Nullable)
#        - member_imageURL (VARCHAR, Nullable)
#        - member_address_city (VARCHAR, Nullable)
#        - member_address_state (VARCHAR, Nullable)
#        - member_address_zip (VARCHAR, Nullable)
#        - member_languages_json (JSONB/TEXT)
#        - member_legacyId (VARCHAR, Nullable)
#        - member_isPremium (BOOLEAN, Nullable)
#        - distanceFromSeekerInMiles (FLOAT, Nullable)
#        - hasCareCheck (BOOLEAN, Nullable)
#        - hasGrantedCriminalBGCAccess (BOOLEAN, Nullable)
#        - hasGrantedMvrBGCAccess (BOOLEAN, Nullable)
#        - hasGrantedPremierBGCAccess (BOOLEAN, Nullable)
#        - hiredTimes (INTEGER, Nullable)
#        - isFavorite (BOOLEAN, Nullable)
#        - isMVREligible (BOOLEAN, Nullable)
#        - isVaccinated (BOOLEAN, Nullable)
#        - providerStatus (VARCHAR, Nullable)
#        - responseRate (INTEGER, Nullable)
#        - responseTime (INTEGER, Nullable)
#        - signUpDate (TIMESTAMP, Nullable)
#        - yearsOfExperience (INTEGER, Nullable)
#        - badges_json (JSONB/TEXT)
#        - backgroundChecks_json (JSONB/TEXT)
#        - educationDegrees_json (JSONB/TEXT)
#        - hiredByCounts_json (JSONB/TEXT)
#        - placeInfo_json (JSONB/TEXT)
#        - recurringAvailability_json (JSONB/TEXT)
#        - nonPrimaryImages_json (JSONB/TEXT)
#        - continuousBackgroundCheck_json (JSONB/TEXT)
#        # Note: profiles_json is used for processing but typically not stored directly
#
#     2. NestedServiceProfiles (Explicit top-level, dynamic inner fields)
#        - nested_profile_pk (PK, SERIAL or UUID - Added during ETL)
#        - profile_id (FK -> Profiles.profile_id)
#        - sub_profile_type (VARCHAR) - e.g., 'commonCaregiverProfile', 'houseKeepingCaregiverProfile'
#        - service_ids_json (JSONB/TEXT)
#        # --- Explicit Simple Sub-Profile Fields (Examples) ---
#        - commonCaregiverProfile_id (VARCHAR, Nullable)
#        - commonCaregiverProfile_repeatClientsCount (INTEGER, Nullable)
#        - seniorCareCaregiverProfile_id (VARCHAR, Nullable)
#        - seniorCareCaregiverProfile_approvalStatus (VARCHAR, Nullable)
#        - seniorCareCaregiverProfile_availabilityFrequency (VARCHAR, Nullable)
#        - seniorCareCaregiverProfile_yearsOfExperience (INTEGER, Nullable)
#        - houseKeepingCaregiverProfile_id (VARCHAR, Nullable)
#        - houseKeepingCaregiverProfile_approvalStatus (VARCHAR, Nullable)
#        - houseKeepingCaregiverProfile_yearsOfExperience (INTEGER, Nullable)
#        - houseKeepingCaregiverProfile_distanceWillingToTravel (INTEGER, Nullable)
#        - childCareCaregiverProfile_id (VARCHAR, Nullable)
#        - childCareCaregiverProfile_numberOfChildren (INTEGER, Nullable)
#        # --- Dynamically Flattened Inner Fields (Examples) ---
#        - commonCaregiverProfile_merchandizedJobInterests_companionCare (BOOLEAN, Nullable)
#        - commonCaregiverProfile_merchandizedJobInterests_lightCleaning (BOOLEAN, Nullable)
#        - seniorCareCaregiverProfile_bio_experienceSummary (TEXT, Nullable)
#        - seniorCareCaregiverProfile_payRange_hourlyRateFrom_amount (VARCHAR -> NUMERIC, Nullable)
#        - seniorCareCaregiverProfile_qualities_cprTrained (BOOLEAN, Nullable)
#        - seniorCareCaregiverProfile_supportedServices_transportation (BOOLEAN, Nullable)
#        - houseKeepingCaregiverProfile_qualities_doesNotSmoke (BOOLEAN, Nullable)
#        - houseKeepingCaregiverProfile_supportedServices_laundry (BOOLEAN, Nullable)
#        # --- JSON Lists within Sub-Profiles (Examples) ---
#        - seniorCareCaregiverProfile_otherQualities_json (JSONB/TEXT)
#        - childCareCaregiverProfile_ageGroups_json (JSONB/TEXT)
#        - childCareCaregiverProfile_rates_json (JSONB/TEXT)
#        - houseKeepingCaregiverProfile_schedule_json (JSONB/TEXT)
#
#     3. Reviews (Explicit Fields)
#        - review_id (PK, VARCHAR)
#        - profile_id (FK -> Profiles.profile_id, Nullable)
#        - source_filename (VARCHAR)
#        - careType (VARCHAR, Nullable)
#        - createTime (TIMESTAMP, Nullable)
#        - deleteTime (TIMESTAMP, Nullable)
#        - description_displayText (TEXT, Nullable)
#        - description_originalText (TEXT, Nullable)
#        - languageCode (VARCHAR, Nullable)
#        - originalSource (VARCHAR, Nullable)
#        - status (VARCHAR, Nullable)
#        - updateSource (VARCHAR, Nullable)
#        - updateTime (TIMESTAMP, Nullable)
#        - verifiedByCare (BOOLEAN, Nullable)
#        - reviewee_providerType (VARCHAR, Nullable)
#        - reviewee_type (VARCHAR, Nullable)
#        - reviewer_imageURL (VARCHAR, Nullable)
#        - reviewer_firstName (VARCHAR, Nullable)
#        - reviewer_lastInitial (VARCHAR, Nullable)
#        - reviewer_source (VARCHAR, Nullable)
#        - reviewer_type (VARCHAR, Nullable)
#        - ratings_json (JSONB/TEXT) -> Normalize to ReviewRatings
#        - retort_json (JSONB/TEXT)
#        - attributes_json (JSONB/TEXT) -> Normalize to ReviewAttributes
#
#     Normalization Strategy Remains Similar:
#     - Normalize JSON fields (languages, badges, checks, degrees, ratings, attributes, lists within nested profiles)
#       into separate tables during the database loading (ETL) phase.

# %%
from etl.sql_modeling import run_etl
run_etl()
# Out:
# 2025-04-14 12:15:54,017 - INFO - [sql_modeling.py:57] - Database engine created successfully.
# 2025-04-14 12:15:54,035 - INFO - [sql_modeling.py:622] - Database session created.
# 2025-04-14 12:15:54,036 - INFO - [sql_modeling.py:626] - Creating database tables if they do not exist...
# 2025-04-14 12:15:54,224 - INFO - [sql_modeling.py:628] - Table creation check complete.
# 2025-04-14 12:15:54,225 - INFO - [sql_modeling.py:633] - Reading main profiles CSV: preprocessed_data\USA\main_profiles_processed.csv
# 2025-04-14 12:15:55,130 - INFO - [sql_modeling.py:288] - Starting to load 11893 main profile records...
# 2025-04-14 12:17:07,291 - INFO - [sql_modeling.py:400] - Finished loading profiles. Loaded: 11893, Skipped due to errors: 0
# 2025-04-14 12:17:07,296 - INFO - [sql_modeling.py:637] - Committed main profiles.
# 2025-04-14 12:17:07,297 - INFO - [sql_modeling.py:645] - Found 6 nested profile CSV files.
# 2025-04-14 12:17:07,298 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_childCareCaregiverProfile_processed.csv (Type: childCareCaregiverProfile)
# 2025-04-14 12:17:07,473 - INFO - [sql_modeling.py:405] - Starting to load 9264 nested 'childCareCaregiverProfile' records...
# 2025-04-14 12:17:30,521 - INFO - [sql_modeling.py:515] - Finished loading nested 'childCareCaregiverProfile'. Loaded: 9264, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:17:30,526 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: childCareCaregiverProfile
# 2025-04-14 12:17:30,527 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_commonCaregiverProfile_processed.csv (Type: commonCaregiverProfile)
# 2025-04-14 12:17:30,568 - INFO - [sql_modeling.py:405] - Starting to load 11893 nested 'commonCaregiverProfile' records...
# 2025-04-14 12:17:58,395 - INFO - [sql_modeling.py:515] - Finished loading nested 'commonCaregiverProfile'. Loaded: 11893, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:17:58,398 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: commonCaregiverProfile
# 2025-04-14 12:17:58,399 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_houseKeepingCaregiverProfile_processed.csv (Type: houseKeepingCaregiverProfile)
# 2025-04-14 12:17:58,454 - INFO - [sql_modeling.py:405] - Starting to load 3356 nested 'houseKeepingCaregiverProfile' records...
# 2025-04-14 12:18:06,756 - INFO - [sql_modeling.py:515] - Finished loading nested 'houseKeepingCaregiverProfile'. Loaded: 3356, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:18:06,759 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: houseKeepingCaregiverProfile
# 2025-04-14 12:18:06,760 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_petCareCaregiverProfile_processed.csv (Type: petCareCaregiverProfile)
# 2025-04-14 12:18:06,867 - INFO - [sql_modeling.py:405] - Starting to load 3242 nested 'petCareCaregiverProfile' records...
# 2025-04-14 12:18:16,049 - INFO - [sql_modeling.py:515] - Finished loading nested 'petCareCaregiverProfile'. Loaded: 3242, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:18:16,052 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: petCareCaregiverProfile
# 2025-04-14 12:18:16,053 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_seniorCareCaregiverProfile_processed.csv (Type: seniorCareCaregiverProfile)
# 2025-04-14 12:18:16,130 - INFO - [sql_modeling.py:405] - Starting to load 4655 nested 'seniorCareCaregiverProfile' records...
# 2025-04-14 12:18:31,900 - INFO - [sql_modeling.py:515] - Finished loading nested 'seniorCareCaregiverProfile'. Loaded: 4655, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:18:31,903 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: seniorCareCaregiverProfile
# 2025-04-14 12:18:31,904 - INFO - [sql_modeling.py:652] - Reading nested profiles CSV: preprocessed_data\USA\nested_tutoringCaregiverProfile_processed.csv (Type: tutoringCaregiverProfile)
# 2025-04-14 12:18:31,946 - INFO - [sql_modeling.py:405] - Starting to load 1391 nested 'tutoringCaregiverProfile' records...
# 2025-04-14 12:18:36,236 - INFO - [sql_modeling.py:515] - Finished loading nested 'tutoringCaregiverProfile'. Loaded: 1391, Skipped: 0, ParentNotFound: 0
# 2025-04-14 12:18:36,239 - INFO - [sql_modeling.py:656] - Committed nested profiles for type: tutoringCaregiverProfile
# 2025-04-14 12:18:36,240 - INFO - [sql_modeling.py:665] - Reading reviews CSV: preprocessed_data\USA\reviews_processed.csv
# 2025-04-14 12:18:36,480 - INFO - [sql_modeling.py:520] - Starting to load 13056 review records...
# 2025-04-14 12:18:37,537 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 11b60f5e-456b-4744-b90c-8ed49efb936e (row 130): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '11b60f5e-456b-4744-b90c-8ed49efb936e', 'profile_id': '1a0f2537-726b-4044-aacc-d02716602faf', 'zip_code': 7008, 'source_filename': 'USA\\07008\\reviews\\CHILD_CARE\\1a0f2537-726b-4044-aacc-d02716602faf_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2023-09-21 16:21:57.893000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'Zainab was an exceptional care taker to my child. She made sure they were well taken care of, followed through with schedule daily schedule . I’d say ... (3 characters truncated) ... eir behavior improved alot more, they felt at home and i felt at ease while at work. I highly recommend Zainab and i know you wont regret having her.', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-01-22 20:39:16.801000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'INDIVIDUAL', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'SEEKER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:18:38,537 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review d85aca68-131f-554a-a96d-237763e3b55d (row 286). Setting profile_id to NULL.
# 2025-04-14 12:18:38,545 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review a9d2af3b-86c3-592a-ac92-90caf5c8bf52 (row 287). Setting profile_id to NULL.
# 2025-04-14 12:18:38,552 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 5ee60cd8-e8d0-5540-bf1a-108510030e39 (row 288). Setting profile_id to NULL.
# 2025-04-14 12:18:38,560 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 5e383145-2ef8-5474-881f-d14407171dea (row 289). Setting profile_id to NULL.
# 2025-04-14 12:18:38,569 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 37d40730-f297-5619-b017-d64667d999da (row 290). Setting profile_id to NULL.
# 2025-04-14 12:18:38,579 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 4993f1b4-ca40-56d1-8f86-35679428baaa (row 291). Setting profile_id to NULL.
# 2025-04-14 12:18:38,587 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 09523d7d-56ae-4a24-a37c-c82e39272e6b (row 292). Setting profile_id to NULL.
# 2025-04-14 12:18:38,597 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 63afaaf0-983b-45b0-866c-5c5e892dcef8 (row 293). Setting profile_id to NULL.
# 2025-04-14 12:18:38,605 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 2c9bfe0a-dfaa-49c5-8039-9ea2b44a43bf (row 294). Setting profile_id to NULL.
# 2025-04-14 12:18:38,614 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 42c4ff31-7e01-45d8-accb-886ee32b99a0 (row 295). Setting profile_id to NULL.
# 2025-04-14 12:18:38,622 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review e390c774-fbc8-4996-89a9-4c350cd1d676 (row 296). Setting profile_id to NULL.
# 2025-04-14 12:18:38,631 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 85ecbf8f-7ba7-4c70-afb4-d89bd59bcce9 (row 297). Setting profile_id to NULL.
# 2025-04-14 12:18:38,639 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 71083a62-f8ad-4180-a7b8-36aebf34b574 (row 298). Setting profile_id to NULL.
# 2025-04-14 12:18:38,647 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 632eea41-85a0-4085-8c9f-04e8b4ac85fa (row 299). Setting profile_id to NULL.
# 2025-04-14 12:18:38,655 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 808bf519-4d5b-4d9c-9ca5-aacbe5f8420f (row 300). Setting profile_id to NULL.
# 2025-04-14 12:18:38,665 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 17823517-8fe1-485c-85f7-a4aee5d17f49 (row 301). Setting profile_id to NULL.
# 2025-04-14 12:18:38,673 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 6665ea26-f326-4a8d-a656-640e1ef059fb (row 302). Setting profile_id to NULL.
# 2025-04-14 12:18:38,681 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 344c5862-3a99-4c25-a66b-184166a13ae1 (row 303). Setting profile_id to NULL.
# 2025-04-14 12:18:38,690 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 1f5cdac9-5569-40dd-8a0b-fcaa43f2a9ba (row 304). Setting profile_id to NULL.
# 2025-04-14 12:18:38,699 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 017818f7-1beb-418c-a9ce-45635d5b7b2c (row 305). Setting profile_id to NULL.
# 2025-04-14 12:18:38,708 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 097403b5-2615-4ed4-95b0-b360b29805ad (row 306). Setting profile_id to NULL.
# 2025-04-14 12:18:38,717 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 6108d286-1864-40ee-a010-41373059cf83 (row 307). Setting profile_id to NULL.
# 2025-04-14 12:18:38,726 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review e6c7a9d8-d824-433e-a7a7-f4c6ff4fcfc4 (row 308). Setting profile_id to NULL.
# 2025-04-14 12:18:38,734 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review a79d0085-e2c9-4674-9b69-06a8e7609602 (row 309). Setting profile_id to NULL.
# 2025-04-14 12:18:38,742 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review b37c04b5-289a-443f-a6df-b4b8c45e13ee (row 310). Setting profile_id to NULL.
# 2025-04-14 12:18:38,752 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 063a09dc-02af-42ef-abee-0021ba95dca2 (row 311). Setting profile_id to NULL.
# 2025-04-14 12:18:38,762 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 54b6011f-5d58-4249-a1e1-ab905799895a (row 312). Setting profile_id to NULL.
# 2025-04-14 12:18:38,772 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 0c25d659-c258-49f8-a248-0b4d466dcca4 (row 313). Setting profile_id to NULL.
# 2025-04-14 12:18:38,782 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review e45a01c8-09e6-44d6-9261-8723bb32af74 (row 314). Setting profile_id to NULL.
# 2025-04-14 12:18:38,791 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 37ae0299-305e-400a-9e11-6d5c21cb71f1 (row 315). Setting profile_id to NULL.
# 2025-04-14 12:18:38,801 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 34e91bf3-cd8b-4b41-8027-d2c99171f804 (row 316). Setting profile_id to NULL.
# 2025-04-14 12:18:38,810 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 4347d331-8ba0-43ab-9fa2-0f78313f8486 (row 317). Setting profile_id to NULL.
# 2025-04-14 12:18:38,819 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 3a8c7f93-ccbd-4c87-b8b0-cf25d3289a78 (row 318). Setting profile_id to NULL.
# 2025-04-14 12:18:38,827 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 05420527-e369-4c43-8570-bc1e5ed70548 (row 319). Setting profile_id to NULL.
# 2025-04-14 12:18:38,836 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 9f8e3557-29f1-4dc6-a6d1-238318d38fcc (row 320). Setting profile_id to NULL.
# 2025-04-14 12:18:38,847 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review bd841bfb-be92-4e6c-87b2-6e055261e271 (row 321). Setting profile_id to NULL.
# 2025-04-14 12:18:38,855 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review fd68b8a3-435e-47d9-b632-dcf6ad205983 (row 322). Setting profile_id to NULL.
# 2025-04-14 12:18:38,865 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 7b3e460c-3333-4421-9f1d-85ed3ba3f5f2 (row 323). Setting profile_id to NULL.
# 2025-04-14 12:18:38,873 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review ca328689-6205-484a-a2cb-59e9ca7d6b14 (row 324). Setting profile_id to NULL.
# 2025-04-14 12:18:38,884 - WARNING - [sql_modeling.py:538] - Parent profile 378573f7-3876-49e5-99ac-b4acd3de2fdf not found for review 99e431e6-be8a-41bf-8818-98a827676944 (row 325). Setting profile_id to NULL.
# 2025-04-14 12:18:46,152 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review ba2455ff-5593-4998-a5ef-6322c918d594 (row 1393): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'ba2455ff-5593-4998-a5ef-6322c918d594', 'profile_id': 'c0a6da4b-db32-4c3e-b8ee-9ea25b84e368', 'zip_code': 7008, 'source_filename': 'USA\\07008\\reviews\\HOUSEKEEPING\\c0a6da4b-db32-4c3e-b8ee-9ea25b84e368_HOUSEKEEPING_1.json', 'care_type': 'HOUSEKEEPING', 'create_time': Timestamp('2023-08-12 17:24:19.900000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': nan, 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-01-12 16:46:51.493000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'INDIVIDUAL', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'SEEKER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:02,637 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 235681c0-218a-5feb-b690-aa07d7cb922b (row 4108): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '235681c0-218a-5feb-b690-aa07d7cb922b', 'profile_id': '599590b5-6d41-49c5-814e-daabefb987d0', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\599590b5-6d41-49c5-814e-daabefb987d0_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2025-03-09 22:08:37.290000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'This was absolutely amazing with my daughter, providing compassionate and attentive care that put us both at ease. Her kindness, patience, and profes ... (73 characters truncated) ... ughter was in the best hands. We are so grateful for her dedication and would highly recommend them to anyone in need of a truly wonderful caregiver!', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2025-03-09 22:08:38.220000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:03,747 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 92f78911-71c3-55c0-b2e4-d9d20544913d (row 4299): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '92f78911-71c3-55c0-b2e4-d9d20544913d', 'profile_id': '62b33d51-cfdd-4eff-a2fe-587d650af9f6', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\62b33d51-cfdd-4eff-a2fe-587d650af9f6_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-07-26 17:24:01.762000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'She’s amazing! \nShe helped me taking care of my kids and my dogs while I was away. Very kind, honest, reliable, responsible and active.', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-07-26 17:24:03.013000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/44/42785444_PGTIjX001z0ZLiFjyXEw9S5cYqV1600', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:04,251 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 30920af7-7fe4-5f87-9fee-31355feb6fee (row 4386): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '30920af7-7fe4-5f87-9fee-31355feb6fee', 'profile_id': '6582c970-9302-460c-8429-f8bd60fb8411', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\6582c970-9302-460c-8429-f8bd60fb8411_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-09-18 18:55:02.223000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'Giea is a very understanding person she has a great sense of humor and very good with helping anyone ', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-09-18 18:55:03.095000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:22,895 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review a59cd047-8de0-40b4-9cfd-719ee101b763 (row 7692): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'a59cd047-8de0-40b4-9cfd-719ee101b763', 'profile_id': 'f149bdf4-20c4-45b1-b48d-b9da0d80a540', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\f149bdf4-20c4-45b1-b48d-b9da0d80a540_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-05-13 21:48:11.115000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': "Jamira's been with us for almost two years now, and she's been a total blessing! She's amazing with the kids, always finding fun ways to help them le ... (82 characters truncated) ... g a hand around the house and doesn't mind getting dinner ready for the little ones if we're running late. Seriously, she's become like family to us!", 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-05-13 21:48:12.333000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/59/44706959_oNntiLmBpzLqq5dzCeIE4qdMniha6p00', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:23,970 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 32da29a8-92b1-47eb-be7d-12eecadc3ba2 (row 7887): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '32da29a8-92b1-47eb-be7d-12eecadc3ba2', 'profile_id': 'f93bef2a-032f-48f4-8a73-5df7d50b810d', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\f93bef2a-032f-48f4-8a73-5df7d50b810d_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-03-21 15:32:46.084000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': "I highly recommend Melenie for any childcare position. She has been watching my son Logan for over 3 years, and I couldn't be happier with the care s ... (549 characters truncated) ... lenie is a great cook and prepares healthy meals for Logan. She also helps him with his homework, which has been a huge help for me as a busy parent.", 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-03-21 15:32:46.799000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/63/44808263_sn0d6hKZzIWQgUu91KWLWUPdQkd0100', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:24,491 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review fd578367-fa77-551d-887e-9e13fce479fd (row 7991): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'fd578367-fa77-551d-887e-9e13fce479fd', 'profile_id': 'fd9cbc91-a1d9-4f0a-a00f-9af1655d151c', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\CHILD_CARE\\fd9cbc91-a1d9-4f0a-a00f-9af1655d151c_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-07-03 19:32:32.493000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': "She's a wonderful person, respectful, well spoken, and dependable me and my children love and appreciate her ", 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-07-03 19:32:36.931000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/71/43607071_swX5CJ4ehItqCMZSKCxNazeqgTTKN200', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:36,446 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review df655293-cee5-5b7a-9234-f31a2d28562f (row 10006): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'df655293-cee5-5b7a-9234-f31a2d28562f', 'profile_id': '9f3f4a14-6d79-4c21-ba6e-b1c29e4c26c2', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\SENIOR_CARE\\9f3f4a14-6d79-4c21-ba6e-b1c29e4c26c2_SENIOR_CARE_1.json', 'care_type': 'SENIOR_CARE', 'create_time': Timestamp('2024-11-08 22:00:11.399000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'She is an excellent caregiver!', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-11-08 22:00:12.526000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/99/41586099_wLKbLt8zxTdN44N2YsZlhW1isjVkDc00', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:37,377 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review c6d0a5c7-f466-554c-bae6-ffc2b4769f23 (row 10170): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'c6d0a5c7-f466-554c-bae6-ffc2b4769f23', 'profile_id': 'be96c404-37b4-4bd8-a13a-144f3365ca60', 'zip_code': 10002, 'source_filename': 'USA\\10002\\reviews\\SENIOR_CARE\\be96c404-37b4-4bd8-a13a-144f3365ca60_SENIOR_CARE_1.json', 'care_type': 'SENIOR_CARE', 'create_time': Timestamp('2024-09-16 15:18:35.864000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'Debra is a very hard and honest person and also reliable great person ', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-11-08 11:24:40.210000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': 'https://www.care.com/s/d/aws/photo/135X135/27/43656127_Y4a0Om7Rg6ZsFlK6l2cp1zqb1nMx700', 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:43,153 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 1d2640a5-9cc9-5880-ae36-46b8c524ed93 (row 11162): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '1d2640a5-9cc9-5880-ae36-46b8c524ed93', 'profile_id': '5bb757bb-cc2c-4c80-ab5d-82780d50727e', 'zip_code': 30306, 'source_filename': 'USA\\30306\\reviews\\CHILD_CARE\\5bb757bb-cc2c-4c80-ab5d-82780d50727e_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-08-06 16:43:55.535000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'I highly recommend Diana, She is amazing! So creative, fun and lovely with my kid. She is very professional, always arrived on time and flexible with my schedules and the most important thing I always felt that my kid was safe with her. ', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-08-06 16:43:55.977000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:45,091 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review e6a0ce86-70a9-5cf9-8cb9-f14a49c8c8e8 (row 11521): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': 'e6a0ce86-70a9-5cf9-8cb9-f14a49c8c8e8', 'profile_id': '8f8c7746-1738-4b0a-8fed-0f596d0a61dd', 'zip_code': 30306, 'source_filename': 'USA\\30306\\reviews\\CHILD_CARE\\8f8c7746-1738-4b0a-8fed-0f596d0a61dd_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2025-01-06 20:39:42.141000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'On time hard working and caring ', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2025-01-06 20:39:43.249000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:45,098 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 7cb506f4-09c4-59ba-9c91-811dbd3c8bae (row 11522): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '7cb506f4-09c4-59ba-9c91-811dbd3c8bae', 'profile_id': '8f8c7746-1738-4b0a-8fed-0f596d0a61dd', 'zip_code': 30306, 'source_filename': 'USA\\30306\\reviews\\CHILD_CARE\\8f8c7746-1738-4b0a-8fed-0f596d0a61dd_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2025-01-06 18:05:27.524000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'I have know. miracle for a few years now. Back in 2022 when I had my son I had to return back to work in the middle of October. I reached out to her  ... (333 characters truncated) ... k , even look under the bed for “monsters” for your child if they’re too scared to take a nap. If you need someone for care I hope you pick Miracle. ', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2025-01-06 18:05:28.244000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:46,456 - ERROR - [sql_modeling.py:603] - SQLAlchemyError loading review 3953b7c5-d835-5ead-bc16-b09e16b22c3a (row 11775): (psycopg2.errors.StringDataRightTruncation) value too long for type character varying(1)
#
# [SQL: INSERT INTO reviews (review_id, profile_id, zip_code, source_filename, care_type, create_time, delete_time, description_display_text, description_original_text, language_code, original_source, status, update_source, update_time, verified_by_care, reviewee_provider_type, reviewee_type, reviewer_image_url, reviewer_first_name, reviewer_last_initial, reviewer_source, reviewer_type, retort_json) VALUES (%(review_id)s, %(profile_id)s, %(zip_code)s, %(source_filename)s, %(care_type)s, %(create_time)s, %(delete_time)s, %(description_display_text)s, %(description_original_text)s, %(language_code)s, %(original_source)s, %(status)s, %(update_source)s, %(update_time)s, %(verified_by_care)s, %(reviewee_provider_type)s, %(reviewee_type)s, %(reviewer_image_url)s, %(reviewer_first_name)s, %(reviewer_last_initial)s, %(reviewer_source)s, %(reviewer_type)s, %(retort_json)s)]
# [parameters: {'review_id': '3953b7c5-d835-5ead-bc16-b09e16b22c3a', 'profile_id': 'b0245cdb-f00f-4ffe-afbb-ff6ac24f284a', 'zip_code': 30306, 'source_filename': 'USA\\30306\\reviews\\CHILD_CARE\\b0245cdb-f00f-4ffe-afbb-ff6ac24f284a_CHILD_CARE_1.json', 'care_type': 'CHILD_CARE', 'create_time': Timestamp('2024-06-13 00:06:47.830000'), 'delete_time': None, 'description_display_text': nan, 'description_original_text': 'Serve was really god and she makes me feel comfortable and confident, highly recommended, thank you Miss Lili❤️❤️❤️', 'language_code': 'en-us', 'original_source': 'MFE', 'status': 'APPROVED', 'update_source': nan, 'update_time': Timestamp('2024-06-13 00:06:48.587000+0000', tz='UTC'), 'verified_by_care': False, 'reviewee_provider_type': 'COMPANY', 'reviewee_type': 'PROVIDER', 'reviewer_image_url': nan, 'reviewer_first_name': nan, 'reviewer_last_initial': nan, 'reviewer_source': 'CZEN', 'reviewer_type': 'PROVIDER', 'retort_json': '{}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# 2025-04-14 12:19:53,311 - INFO - [sql_modeling.py:610] - Finished loading reviews. Loaded: 13042, Skipped: 0, ParentNotFound: 40
# 2025-04-14 12:19:53,316 - INFO - [sql_modeling.py:669] - Committed reviews.
# 2025-04-14 12:19:53,317 - INFO - [sql_modeling.py:673] - ETL process completed successfully!
# 2025-04-14 12:19:53,317 - INFO - [sql_modeling.py:685] - Closing database session.

# %%
from test import run_etl
run_etl()
# Out:
# 2025-04-24 16:33:51,454 - INFO - [test.py:69] - Database engine created successfully.
# 2025-04-24 16:33:51,635 - INFO - [test.py:1399] - DB session created.
# 2025-04-24 16:33:51,637 - INFO - [test.py:1401] - Creating DB tables if needed...
# 2025-04-24 16:33:52,237 - INFO - [test.py:1403] - Table check complete.
# 2025-04-24 16:33:52,241 - INFO - [test.py:1407] - Reading main profiles: preprocessed_data\USA\main_profiles_processed.csv
# 2025-04-24 16:33:54,604 - INFO - [test.py:840] - Starting to load 11893 main profile records...
# 2025-04-24 16:37:40,387 - INFO - [test.py:1030] - Profiles load done. Loaded: 11893, Skipped: 0
# 2025-04-24 16:37:40,410 - INFO - [test.py:1411] - Committed main profiles.
# 2025-04-24 16:37:40,412 - INFO - [test.py:1419] - Found 6 nested profile CSV files.
# 2025-04-24 16:37:40,413 - INFO - [test.py:1426] - Reading nested profiles: preprocessed_data\USA\nested_childCareCaregiverProfile_processed.csv (Type: childCareCaregiverProfile)
# 2025-04-24 16:37:40,837 - INFO - [test.py:1044] - Starting load 9264 nested 'childCareCaregiverProfile' records into nested_childcare_profiles...
# 2025-04-24 16:40:22,257 - INFO - [test.py:1301] - Nested 'childCareCaregiverProfile' load done. Loaded: 9264, Skipped: 0, ParentNotFound: 0, PKs assigned: 9264
# 2025-04-24 16:40:22,288 - INFO - [test.py:1432] - Committed nested profiles: childCareCaregiverProfile
# 2025-04-24 16:40:22,290 - INFO - [test.py:1426] - Reading nested profiles: preprocessed_data\USA\nested_commonCaregiverProfile_processed.csv (Type: commonCaregiverProfile)
# 2025-04-24 16:40:22,382 - INFO - [test.py:1044] - Starting load 11893 nested 'commonCaregiverProfile' records into nested_common_profiles...
# 2025-04-24 16:42:22,102 - INFO - [test.py:1301] - Nested 'commonCaregiverProfile' load done. Loaded: 11893, Skipped: 0, ParentNotFound: 0, PKs assigned: 11893
# 2025-04-24 16:42:22,111 - INFO - [test.py:1432] - Committed nested profiles: commonCaregiverProfile
# 2025-04-24 16:42:22,113 - INFO - [test.py:1426] - Reading nested profiles: preprocessed_data\USA\nested_houseKeepingCaregiverProfile_processed.csv (Type: houseKeepingCaregiverProfile)
# 2025-04-24 16:42:22,232 - INFO - [test.py:1044] - Starting load 3356 nested 'houseKeepingCaregiverProfile' records into nested_housekeeping_profiles...

# %%
import json

# Example JSON string
json_string = '''
{
  "name": "Alice",
  "is_active": true,
  "count": 42,
  "status": "ok",
  "is_verified": false,
  "maybe_boolean": "true"
}
'''

# Parse the JSON string into a Python dictionary
data = json.loads(json_string)

# --- Checking specific values ---

# Check 'is_active' which is a JSON true -> Python True
value_active = data.get('is_active')
is_bool_active = isinstance(value_active, bool)
print(f"Value of 'is_active': {value_active} (Type: {type(value_active)})")
print(f"Is 'is_active' a boolean? {is_bool_active}") # Output: True

print("-" * 20)

# Check 'is_verified' which is a JSON false -> Python False
value_verified = data.get('is_verified')
is_bool_verified = isinstance(value_verified, bool)
print(f"Value of 'is_verified': {value_verified} (Type: {type(value_verified)})")
print(f"Is 'is_verified' a boolean? {is_bool_verified}") # Output: True

print("-" * 20)

# Check 'count' which is a number -> Python int
value_count = data.get('count')
is_bool_count = isinstance(value_count, bool)
print(f"Value of 'count': {value_count} (Type: {type(value_count)})")
print(f"Is 'count' a boolean? {is_bool_count}") # Output: False

print("-" * 20)

# Check 'maybe_boolean' which is a string -> Python str
value_maybe = data.get('maybe_boolean')
is_bool_maybe = isinstance(value_maybe, bool)
print(f"Value of 'maybe_boolean': {value_maybe} (Type: {type(value_maybe)})")
print(f"Is 'maybe_boolean' a boolean? {is_bool_maybe}") # Output: False

print("-" * 20)

# --- Iterating and checking ---
print("Iterating through all values:")
for key, value in data.items():
    if isinstance(value, bool):
        print(f"  Key '{key}' has a boolean value: {value}")
    else:
        print(f"  Key '{key}' has a non-boolean value: {value} (Type: {type(value).__name__})")
# Out:
# Value of 'is_active': True (Type: <class 'bool'>)
# Is 'is_active' a boolean? True
# --------------------
# Value of 'is_verified': False (Type: <class 'bool'>)
# Is 'is_verified' a boolean? True
# --------------------
# Value of 'count': 42 (Type: <class 'int'>)
# Is 'count' a boolean? False
# --------------------
# Value of 'maybe_boolean': true (Type: <class 'str'>)
# Is 'maybe_boolean' a boolean? False
# --------------------
# Iterating through all values:
#   Key 'name' has a non-boolean value: Alice (Type: str)
#   Key 'is_active' has a boolean value: True
#   Key 'count' has a non-boolean value: 42 (Type: int)
#   Key 'status' has a non-boolean value: ok (Type: str)
#   Key 'is_verified' has a boolean value: False
#   Key 'maybe_boolean' has a non-boolean value: true (Type: str)
