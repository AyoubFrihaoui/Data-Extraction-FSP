# %%
from test import run_quality

run_quality()
# Out:
# 2025-04-08 17:01:04,634 - INFO - [test.py:709] - Starting Data Quality Check Script for USA/10002
# 2025-04-08 17:01:04,637 - INFO - [test.py:720] - --- Processing Profiles ---
# 2025-04-08 17:01:04,639 - INFO - [test.py:721] - Input Dir: raw_data\USA\10002\all_profiles
# 2025-04-08 17:01:04,640 - INFO - [test.py:722] - Output Dir: preprocessed_data\USA\10002
# 2025-04-08 17:01:04,641 - INFO - [test.py:67] - Scanning for JSON files in: raw_data\USA\10002\all_profiles
# 2025-04-08 17:01:07,954 - INFO - [test.py:77] - Scanned 16628 files. Found 8314 valid JSON files in raw_data\USA\10002\all_profiles.
# 2025-04-08 17:01:15,428 - INFO - [test.py:368] - Created DataFrame for main_profiles with 8314 records and 40 columns.
# 2025-04-08 17:01:15,437 - INFO - [test.py:444] - --- Running Quality Checks for main_profiles (8314 rows) ---
# 2025-04-08 17:01:15,446 - INFO - [test.py:447] - Data types PRE-validation for main_profiles:
# string                 25
# boolean                 9
# ...
