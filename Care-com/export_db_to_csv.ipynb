# %%
# --- Configuration ---
import os
import pandas as pd
from sqlalchemy import create_engine, inspect
from getpass import getpass
from config import CARE_COM_PASSWORD

# Securely prompt for password
#CARE_COM_PASSWORD = getpass("Enter PostgreSQL password:")

# PostgreSQL connection URI
DATABASE_URI = f"postgresql://postgres:{CARE_COM_PASSWORD}@localhost:5432/care-com_db3"

# Output directory for CSVs
EXPORT_DIR = "preprocessed_data/csv_db_files"
os.makedirs(EXPORT_DIR, exist_ok=True)

# Create SQLAlchemy engine
engine = create_engine(DATABASE_URI)
inspector = inspect(engine)

# %%
def export_all_postgres_tables_to_csv(engine, export_dir):
    """
    Export all tables from the connected PostgreSQL DB into separate CSV files.
    """
    table_names = inspector.get_table_names()
    print(f"🗃 Found {len(table_names)} tables: {table_names}\n")

    for table in table_names:
        print(f"➡ Exporting: {table}")
        df = pd.read_sql_table(table, engine)
        file_path = os.path.join(export_dir, f"{table}.csv")
        df.to_csv(file_path, index=False)
        print(f"+ Saved: {file_path}")

    print("\n== All tables exported successfully!")

# Run the export
export_all_postgres_tables_to_csv(engine, EXPORT_DIR)
# Out:
# 🗃 Found 32 tables: ['profiles', 'profile_availability', 'profile_offered_services', 'profile_languages', 'profile_badges', 'profile_background_checks', 'profile_education_degrees', 'profile_non_primary_images', 'nested_common_profiles', 'nested_childcare_profiles', 'nested_housekeeping_profiles', 'nested_petcare_profiles', 'nested_seniorcare_profiles', 'nested_tutoring_profiles', 'reviews', 'nested_common_interests', 'nested_childcare_age_groups', 'nested_childcare_qualities', 'nested_childcare_services', 'nested_housekeeping_qualities', 'nested_housekeeping_services', 'nested_petcare_species', 'nested_petcare_activity_rates', 'nested_petcare_service_rates', 'nested_petcare_qualities', 'nested_petcare_services', 'nested_seniorcare_qualities', 'nested_seniorcare_services', 'nested_tutoring_qualities', 'nested_tutoring_services', 'review_ratings', 'review_attributes']
#
# ➡ Exporting: profiles
# + Saved: preprocessed_data/csv_db_files\profiles.csv
# ➡ Exporting: profile_availability
# + Saved: preprocessed_data/csv_db_files\profile_availability.csv
# ➡ Exporting: profile_offered_services
# + Saved: preprocessed_data/csv_db_files\profile_offered_services.csv
# ➡ Exporting: profile_languages
# + Saved: preprocessed_data/csv_db_files\profile_languages.csv
# ➡ Exporting: profile_badges
# + Saved: preprocessed_data/csv_db_files\profile_badges.csv
# ➡ Exporting: profile_background_checks
# + Saved: preprocessed_data/csv_db_files\profile_background_checks.csv
# ➡ Exporting: profile_education_degrees
# + Saved: preprocessed_data/csv_db_files\profile_education_degrees.csv
# ➡ Exporting: profile_non_primary_images
# + Saved: preprocessed_data/csv_db_files\profile_non_primary_images.csv
# ➡ Exporting: nested_common_profiles
# + Saved: preprocessed_data/csv_db_files\nested_common_profiles.csv
# ➡ Exporting: nested_childcare_profiles
# + Saved: preprocessed_data/csv_db_files\nested_childcare_profiles.csv
# ➡ Exporting: nested_housekeeping_profiles
# + Saved: preprocessed_data/csv_db_files\nested_housekeeping_profiles.csv
# ➡ Exporting: nested_petcare_profiles
# + Saved: preprocessed_data/csv_db_files\nested_petcare_profiles.csv
# ➡ Exporting: nested_seniorcare_profiles
# + Saved: preprocessed_data/csv_db_files\nested_seniorcare_profiles.csv
# ➡ Exporting: nested_tutoring_profiles
# + Saved: preprocessed_data/csv_db_files\nested_tutoring_profiles.csv
# ➡ Exporting: reviews
# + Saved: preprocessed_data/csv_db_files\reviews.csv
# ➡ Exporting: nested_common_interests
# + Saved: preprocessed_data/csv_db_files\nested_common_interests.csv
# ➡ Exporting: nested_childcare_age_groups
# + Saved: preprocessed_data/csv_db_files\nested_childcare_age_groups.csv
# ➡ Exporting: nested_childcare_qualities
# + Saved: preprocessed_data/csv_db_files\nested_childcare_qualities.csv
# ➡ Exporting: nested_childcare_services
# + Saved: preprocessed_data/csv_db_files\nested_childcare_services.csv
# ➡ Exporting: nested_housekeeping_qualities
# + Saved: preprocessed_data/csv_db_files\nested_housekeeping_qualities.csv
# ➡ Exporting: nested_housekeeping_services
# + Saved: preprocessed_data/csv_db_files\nested_housekeeping_services.csv
# ➡ Exporting: nested_petcare_species
# + Saved: preprocessed_data/csv_db_files\nested_petcare_species.csv
# ➡ Exporting: nested_petcare_activity_rates
# + Saved: preprocessed_data/csv_db_files\nested_petcare_activity_rates.csv
# ➡ Exporting: nested_petcare_service_rates
# + Saved: preprocessed_data/csv_db_files\nested_petcare_service_rates.csv
# ➡ Exporting: nested_petcare_qualities
# + Saved: preprocessed_data/csv_db_files\nested_petcare_qualities.csv
# ➡ Exporting: nested_petcare_services
# + Saved: preprocessed_data/csv_db_files\nested_petcare_services.csv
# ➡ Exporting: nested_seniorcare_qualities
# + Saved: preprocessed_data/csv_db_files\nested_seniorcare_qualities.csv
# ➡ Exporting: nested_seniorcare_services
# + Saved: preprocessed_data/csv_db_files\nested_seniorcare_services.csv
# ➡ Exporting: nested_tutoring_qualities
# + Saved: preprocessed_data/csv_db_files\nested_tutoring_qualities.csv
# ➡ Exporting: nested_tutoring_services
# + Saved: preprocessed_data/csv_db_files\nested_tutoring_services.csv
# ➡ Exporting: review_ratings
# + Saved: preprocessed_data/csv_db_files\review_ratings.csv
# ➡ Exporting: review_attributes
# + Saved: preprocessed_data/csv_db_files\review_attributes.csv
#
# == All tables exported successfully!
