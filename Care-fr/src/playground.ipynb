# %%
import requests

url = "https://www.care.com/fr-fr/profiles?sort=bestMatch&order=asc&isRefinedSearch=true&verticalId=childCare&radius=20&geoRegionId=POSTCODE-FR-75001&geoRegionSearch=75001+Paris"

payload = {}
headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
  'priority': 'u=0, i',
  'referer': 'https://www.care.com/fr-fr/profiles?sort=bestMatch&order=asc&isRefinedSearch=true&verticalId=childCare&radius=50&geoRegionId=POSTCODE-FR-75001&geoRegionSearch=75001+Paris',
  'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
  'Cookie': 'OptanonAlertBoxClosed=2024-12-31T17:01:44.628Z; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Mar+13+2025+15%3A35%3A02+GMT%2B0100+(Central+European+Standard+Time)&version=202402.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0&geolocation=DZ%3B23&AwaitingReconsent=false; care_did=35cb1452-a85f-4a6b-b61f-de2608774036; visitorId=095aef12-47d4-44eb-98b8-2af0b8583033; _ga=GA1.1.1085811908.1734524197; _ga_C0SBX7K9HC=GS1.1.1735664504.4.0.1735664504.0.0.0; n_vis=dom-gold-prod-webapp-b6.use.dom.carezen.net1737068549682; mt.v=2.1613722628.1737230292986; FPID=FPID2.2.BPrVcZKCv2awFVVKWM40GNaYZDYCC1UheK3RWDtrubQ%3D.1734524197; FPAU=1.2.983991293.1737230295; enrollment-session-id=7ba1a2d2-c3f6-485a-9c8c-34e2897e207c; __ssid=05bf5143cfec5e51279a744121cd4ce; _uetvid=8ed58930d5d611ef84f2813836146bc7; _scid=fC9MXNBP6zPw8rpkqI2kZJI0CNhYgrd_; _scid_r=fC9MXNBP6zPw8rpkqI2kZJI0CNhYgrd_; csc-session=csc.1.CiDEMYm6RcPriEuWoSj31xlL0IYLFauIoOGv5gvPVy7lPQ.UyM9IsNAptWfgVq0CXIQyAB-mY2UkX4bFUGDMiRj24U; care_mid=bbfcca47-68db-4b53-b848-f2c125b6498d; n_tc=2416; csc=dom-gold-prod-webapp-b1.use.dom.carezen.net1739459038957; vc=55232590-185b-4b19-b39f-95ae05f531a5; sc=S9XMqLsR0dwHjNsGkEEGMkTE2zkF*FoSpyYXuQYgi_E.; rc=57575350%2C20250316042037; ROUTE2=d; OptanonAlertBoxClosed=2025-02-15T07:00:20.964Z; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Feb+15+2025+08%3A00%3A21+GMT%2B0100+(Central+European+Standard+Time)&version=202405.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=1db311e6-fde8-4f46-ba75-75166c5999ab&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=&AwaitingReconsent=false&geolocation=DZ%3B23; FPC=34a11e50-05df-4448-a12a-5ec6c78c07b8; amplitude_id_49ee77491a2b775cf48ecf4a55ce04c5care.com=; ahoy_visitor=2117000c-02b2-4ee8-bf39-c3f128cf1798; ahoy_track=true; JSESSIONID=F10A444677BF5916B99BC49B5CF6F0A1; frsc=DaCEVs
f5-a6a3-d24abd4f7fa8.NjY5ODQwNzU=..1im7o39ib.1im7udl6l.4bu.1b.6bp; utag_main=v_id:0193d9b2cecc001fda0d9dcc3f200506f002506700a53$_sn:8$_ss:0$_st:1741878302857$ses_id:1741873448607%3Bexp-session$_pn:11%3Bexp-session; bm_sv=3E4DE23E08265E7A6DD74D16452BD457~~1; RT="z=1&dm=www.care.com&si=34a86a36-f101-4c49-ad80-d3a06f422bab&ss=m87cpqz3&sl=e&tt=lus&obo=5&rl=1&nu=545joae6&cl=3ljxi&ld=3ljxo&r=hncjibqy&ul=3ljxp"; ak_bmsc=2D5DA205D0F092CAABDBA522CE15FCC2~000000000000000000000000000000~; care_did=35cb1452-a85f-4a6b-b61f-de2608774036; EUWPRD_SESSIONID=C14E4B723E222023FC52E7098E5216D2; care_mid=bbfcca47-68db-4b53-b848-f2c125b6498d; csc-session=csc.1.CiDEMYm6RcPriEuWoSj31xlL0IYLFauIoOGv5gvPVy7lPQ.UyM9IsNAptWfgVq0CXIQyAB-mY2UkX4bFUGDMiRj24U; csc-session-ttl=1745835423; intl_member=...; intl_mid=14d6d6cd-064c-4806-85c0-8eee99aa7661; intl_tmc=...; ukcaredotcom_remember_me=NzY4JTJCamxtcE9ENXBmMzBLRVpiV0JBJTNEJTNEOjNSVCUyRnEza00yQTZDa3U0VTFHQWNuQSUzRCUzRA'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# <!doctype html>
# <html>
# 	<!-- appHost: intl-gold-euwprd-webapp-g2.euw.intl.carezen.net-->
#
#
#
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="fr-FR"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="fr-FR"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="fr-FR"> <![endif]-->
#
# <!--[if gt IE 8]><!--> <html class="no-js" lang="fr-FR"> <!--<![endif]-->
# 	<head>
# ...

# %%
from scrapers.profiles_ids_scraper import ProfileIDScraper
from config import AUTH_TOKEN
try:
    # You can override default values here if needed.
    scraper = ProfileIDScraper(
        postal_code="75001",
        care_type="childCare",
        results_per_page=50,
        base_url="https://www.care.com/fr-fr/profiles",
        auth_token=AUTH_TOKEN  # Replace with token string if necessary.
    )
    scraper.scrape()
except Exception as e:
    print(f"Error: {e}")
# Out:
# 2025-03-14 14:21:18,782 - INFO - Fetching URL: https://www.care.com/fr-fr/profiles?sort=bestMatch&order=asc&isRefinedSearch=true&verticalId=childCare&radius=30&geoRegionId=POSTCODE-FR-75001&geoRegionSearch=75001+Paris&max=50&offset=0&id=pagination
# 2025-03-14 14:21:22,896 - DEBUG - Total results extracted: 407
# 2025-03-14 14:21:22,896 - INFO - Total results found: 407
# 2025-03-14 14:21:22,897 - DEBUG - Extracted IDs: ['8743303', '5355869', '8797369', '5449629', '7798579', '3591674', '4624350', '5966741', '8694118', '5775649', '9138062', '8985895', '9043457', '7201963', '8517129', '9139964', '9137823', '9136261', '9137602', '9138039', '9121801', '9131322', '9113403', '9112945', '9111716', '9132820', '9119507', '9121915', '9123327', '9126849', '9079976', '9123950', '9127771', '9131790', '9127349', '9115298', '6096263', '9123142', '9115707', '9124135', '9120062', '9114636', '9115064', '9097724', '9083776', '9097797', '9104981', '8059478', '9105389', '9070954']
# ...
