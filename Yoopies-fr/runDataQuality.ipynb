# %%
from etl.data_quality_check import run_data_quality_checks

run_data_quality_checks()
# Out:
# 2025-05-05 14:46:30,291 - INFO - [data_quality_check.py:1163] - --- Starting Yoopies Data Aggregation, QC, and Normalization (v2) ---
# 2025-05-05 14:46:30,294 - INFO - [data_quality_check.py:1166] - Input base: data\raw\yoopies, Output base: preprocessed_data\yoopies
# 2025-05-05 14:46:30,299 - INFO - [data_quality_check.py:102] - Scanning for page_*.json files recursively in: data\raw\yoopies
# 2025-05-05 14:47:12,592 - INFO - [data_quality_check.py:120] - Scanned 517 potential page files. Loaded 517 files.
# 2025-05-05 14:47:12,595 - INFO - [data_quality_check.py:320] - Aggregating data from 517 loaded page files...
# 2025-05-05 14:48:32,952 - INFO - [data_quality_check.py:391] - Created aggregated DataFrame with 51475 records (51475 processed edges) and 43 columns.
# 2025-05-05 14:48:33,173 - INFO - [data_quality_check.py:1185] - Dropped 0 ads missing ad_id.
# 2025-05-05 14:48:33,315 - INFO - [data_quality_check.py:1188] - Removed 2270 duplicate ads.
# ...

# %%
from test import run_data_quality_checks
run_data_quality_checks()
# Out:
# 2025-04-28 19:07:37,639 - INFO - [test.py:1157] - --- Starting Yoopies Data Aggregation, QC, and Normalization (v2) ---
# 2025-04-28 19:07:37,644 - INFO - [test.py:1160] - Input base: data\raw\yoopies, Output base: preprocessed_data\yoopies
# 2025-04-28 19:07:37,647 - INFO - [test.py:102] - Scanning for page_*.json files recursively in: data\raw\yoopies
# 2025-04-28 19:08:17,051 - INFO - [test.py:120] - Scanned 517 potential page files. Loaded 517 files.
# 2025-04-28 19:08:17,073 - INFO - [test.py:319] - Aggregating data from 517 loaded page files...
# 2025-04-28 19:08:32,909 - INFO - [test.py:390] - Created aggregated DataFrame with 51475 records (51475 processed edges) and 43 columns.
# 2025-04-28 19:08:33,273 - INFO - [test.py:1179] - Dropped 0 ads missing ad_id.
# 2025-04-28 19:08:33,545 - INFO - [test.py:1182] - Removed 2270 duplicate ads.
# 2025-04-28 19:08:33,548 - INFO - [test.py:1183] - Ad count after dedupe: 49205
# ...

# %%
# Interactive or separate script
from etl.sql_modeling import create_database_schema
create_database_schema()
# Out:
# 2025-04-28 16:18:08,208 - INFO - [sql_modeling.py:81] - Database engine created successfully.
# 2025-04-28 16:18:08,368 - INFO - [sql_modeling.py:83] - Database connection successful.
# 2025-04-28 16:18:08,413 - INFO - [sql_modeling.py:767] - Attempting to create database schema via Base.metadata.create_all...
# 2025-04-28 16:18:08,521 - ERROR - [sql_modeling.py:772] - Schema creation error: (psycopg2.errors.DuplicateTable) relation "ix_ads_user_id" already exists
#
# [SQL: CREATE INDEX ix_ads_user_id ON ads (user_id)]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Traceback (most recent call last):
#   File "c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py", line 1969, in _exec_single_context
#     self.dialect.do_execute(
#   File "c:\Python311\Lib\site-packages\sqlalchemy\engine\default.py", line 922, in do_execute
#     cursor.execute(statement, parameters)
# psycopg2.errors.DuplicateTable: relation "ix_ads_user_id" already exists
#
#
# ...

# %%
from test3 import run_etl_pipeline
run_etl_pipeline()
# Out:
# 2025-04-28 19:17:08,551 - INFO - [test3.py:597] - Database engine created successfully.
# 2025-04-28 19:17:08,556 - INFO - [test3.py:1650] - Starting ETL Script: Load Processed CSVs to PostgreSQL DB for Yoopies France
# 2025-04-28 19:17:08,558 - INFO - [test3.py:1569] - DB session created.
# 2025-04-28 19:17:08,561 - INFO - [test3.py:1572] - Creating DB tables if needed...
# 2025-04-28 19:17:09,022 - INFO - [test3.py:1575] - Table check complete.
# 2025-04-28 19:17:09,025 - INFO - [test3.py:617] - Reading users: preprocessed_data\yoopies\users_processed.csv
# 2025-04-28 19:17:09,416 - INFO - [test3.py:629] - Starting to load 37587 user records...
# 2025-04-28 19:19:37,318 - INFO - [test3.py:685] - Users load done. Loaded: 37587, Skipped: 0
# 2025-04-28 19:19:37,330 - INFO - [test3.py:1587] - Committed Users.
# 2025-04-28 19:19:37,333 - INFO - [test3.py:781] - Reading ads: preprocessed_data\yoopies\flattened_ads_processed.csv
# ...
