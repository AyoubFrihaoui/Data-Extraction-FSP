# %%
import requests
import json

url = "https://yoopies.fr/graphql"

payload = "{\"query\":\"query getAds($after: String, $filters: AdsFiltersInput!, $sortBy: AdSearchSortByEnum, $locale: String, $currentUserId: Int, $service: ServiceEnum, $page: Int, $first: Int!) {\\n  ads(\\n    first: $first\\n    after: $after\\n    filters: $filters\\n    sortBy: $sortBy\\n    locale: $locale\\n    page: $page\\n  ) {\\n    count\\n    countPages\\n    perPage\\n    currentPage\\n    distance\\n    pageInfo {\\n      hasNextPage\\n      hasPreviousPage\\n      endCursor\\n      __typename\\n    }\\n    edges {\\n      node {\\n        score\\n        ad {\\n          id\\n          slug {\\n            title\\n            city\\n            __typename\\n          }\\n          title\\n          content\\n          type\\n          status\\n          createdAt\\n          updatedAt\\n          categories {\\n            service\\n            category\\n            __typename\\n          }\\n          ... on EmployerAd {\\n            startDate\\n            __typename\\n          }\\n          ... on ApplicantAd {\\n            experienceAmount\\n            badges {\\n              name\\n              additionalData\\n              __typename\\n            }\\n            employmentTypes {\\n              id\\n              careTypes {\\n                id\\n                rateTypes {\\n                  id\\n                  rate {\\n                    amount\\n                    timeUnit\\n                    commission\\n                    __typename\\n                  }\\n                  __typename\\n                }\\n                __typename\\n              }\\n              __typename\\n            }\\n            tags {\\n              primaryService\\n              primaryCategory\\n              canDoService\\n              canDoCategory\\n              canDoTypes\\n              extraService\\n              languages {\\n                code\\n                __typename\\n              }\\n              workingConditions {\\n                shareRoom\\n                workWithCoworker\\n                __typename\\n              }\\n              apartmentDetails {\\n                houseType\\n                houseSurface\\n                gardenType\\n                __typename\\n              }\\n              __typename\\n            }\\n            __typename\\n          }\\n          ... on SitterAd {\\n            parentAdType\\n            childminderSlots {\\n              occupiedSlots {\\n                available\\n                estimatedAvailabilityDate\\n                ageRange\\n                careTypes\\n                __typename\\n              }\\n              maxAge\\n              __typename\\n            }\\n            __typename\\n          }\\n          ... on TeacherAd {\\n            lessons {\\n              lessonLevel\\n              lessonType\\n              __typename\\n            }\\n            __typename\\n          }\\n          ... on ParentAd {\\n            parentAdType\\n            duration\\n            __typename\\n          }\\n          address {\\n            latitude\\n            longitude\\n            city\\n            cityKey\\n            country\\n            zipCode\\n            __typename\\n          }\\n          user {\\n            id\\n            enabled\\n            baseType\\n            roles\\n            photos {\\n              thumbnail\\n              large\\n              extra_large\\n              __typename\\n            }\\n            isVerified\\n            firstName\\n            lastName\\n            threadsConnections(first: 1, filters: {user: $currentUserId, service: $service}) {\\n              edges {\\n                node {\\n                  id\\n                  __typename\\n                }\\n                __typename\\n              }\\n              __typename\\n            }\\n            ... on Applicant {\\n              hasAEStatus\\n              age\\n              grades {\\n                count\\n                average\\n                edges {\\n                  node {\\n                    owner {\\n                      firstName\\n                      lastName\\n                      __typename\\n                    }\\n                    content\\n                    generalGrade\\n                    experienceName\\n                    __typename\\n                  }\\n                  __typename\\n                }\\n                __typename\\n              }\\n              options {\\n                visaExpiryDate\\n                __typename\\n              }\\n              __typename\\n            }\\n            ... on Employer {\\n              children {\\n                id\\n                ageRange\\n                __typename\\n              }\\n              __typename\\n            }\\n            __typename\\n          }\\n          __typename\\n        }\\n        __typename\\n      }\\n      __typename\\n    }\\n    __typename\\n  }\\n}\\n\",\"variables\":{\"after\":\"\",\"sortBy\":\"RELEVANCE\",\"locale\":\"fr_FR\",\"filters\":{\"type\":\"SITTER\",\"sitterFilters\":{\"skills\":[],\"distance\":50,\"parentAdType\":[],\"specialAvailability\":[],\"experienceYears\":null,\"ageRange\":{\"ageMin\":16,\"ageMax\":90},\"address\":{\"country\":\"France\",\"countryCode\":\"FR\",\"street\":\"\",\"zipCode\":\"75000\",\"city\":\"Paris\",\"latitude\":48.853495,\"longitude\":2.348391,\"name\":\"Paris, France\"},\"increaseDistance\":true}},\"currentUserId\":null,\"service\":\"CHILDCARE\",\"page\":1,\"first\":10}}"
headers = {
  'accept': '*/*',
  'accept-language': 'en-US,en;q=0.9',
  'baggage': 'sentry-environment=production,sentry-release=6deedcdc89eb92b34f1b1d1271166d967715b4f0,sentry-public_key=b665305b897af0236397145fffb5db66,sentry-trace_id=0cbfc623560a424ebdc8152093164b9a,sentry-sample_rate=0.1,sentry-transaction=GET%20%2Frecherche-baby-sitting%2Fresults,sentry-sampled=false',
  'content-type': 'application/json',
  'fromhost': 'yoopies.fr',
  'origin': 'https://yoopies.fr',
  'priority': 'u=1, i',
  'referer': 'https://yoopies.fr/recherche-baby-sitting/results?c=bordeaux',
  'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'sentry-trace': '0cbfc623560a424ebdc8152093164b9a-b97e745cc2d35f53-0',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
  'Cookie': '_gcl_au=1.1.1306788882.1743408872; gtm_initialTrafficSource=utmcsr=google|utmcmd=organic|utmccn=(not set)|utmctr=(not provided); __utmzzses=1; gtm_session=1; firstAccessYoopies=https://yoopies.fr/; yoopies-spses.9fbd=*; _ga=GA1.1.169034706.1743408872; axeptio_authorized_vendors=%2C%2C; ab.storage.deviceId.4ce5672b-fcad-4636-ab80-3d8ec8e3e400=%7B%22g%22%3A%22e8573076-5329-2268-bb6b-ec009fe1deef%22%2C%22c%22%3A1743408872451%2C%22l%22%3A1743408872451%7D; _fbp=fb.1.1743408872471.63662714042753841; _hjSession_372592=eyJpZCI6ImVhOGUxN2ExLTJkMmEtNDI3OS05NTZiLThmMjFmNzZhNmQ3NSIsImMiOjE3NDM0MDg4NzI0OTYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _hdu=hdu_rSsb0gPKZxcqf0JYRAdqKYhFwQkLhfCl; _hds=hds_rICtb63grGlJMG8NWFZXj2dNyFczMj5p; cookieLegal=true; intercom-id-spudblno=8556d70d-c742-4a1e-9ad7-8b21cf399291; intercom-session-spudblno=; intercom-device-id-spudblno=5903e95d-19f2-4a06-a966-f49ed098cf4a; axeptio_all_vendors=%2Cgoogle_analytics%2Cgoogle_ads%2Cfacebook_pixel%2Camplitude%2Chotjar%2Cintercom%2CGoogle_Ads%2C; axeptio_cookies={%22$$token%22:%22jaip9wbz0olh0xi0r8jb%22%2C%22$$date%22:%222025-03-31T08:14:40.413Z%22%2C%22$$cookiesVersion%22:{%22name%22:%22yoopies.fr%22%2C%22identifier%22:%226058c8c925fdd05e1b1a6e23%22}%2C%22google_analytics%22:false%2C%22google_ads%22:false%2C%22facebook_pixel%22:false%2C%22amplitude%22:false%2C%22hotjar%22:false%2C%22intercom%22:false%2C%22Google_Ads%22:false%2C%22$$completed%22:true}; device_view=full; viewedOuibounceModal=true; type=parent; address=%7B%22formattedAddress%22%3A%22Bordeaux%2C%20Gironde%2C%20France%22%2C%22country%22%3A%22France%22%2C%22countryCode%22%3A%22FR%22%2C%22street%22%3A%22%22%2C%22zipCode%22%3A%2233000%22%2C%22city%22%3A%22Bordeaux%22%2C%22latitude%22%3A44.841225%2C%22longitude%22%3A-0.580036%7D; gtm_route_name=search; gtm_referral_route_name=search; _hjSessionUser_372592=eyJpZCI6IjU0Mjc0ZjNmLTI2OGMtNTlhYi1iNjM5LWI3YzNkNWExNGZlZiIsImNyZWF0ZWQiOjE3NDM0MDg4NzI0OTUsImV4aXN0aW5nIjp0cnVlfQ==; email=frihaouiayoube%40gmail.com; ab.storage.sessionId.4ce5672b-fcad-4636-ab80-3d8ec8e3e400=%7B%22g%22%3A%229aed5c74-a002-23fb-5c3b-12cd8f0882e6%22%2C%22e%22%3A1743410804598%2C%22c%22%3A1743408872449%2C%22l%22%3A1743409004598%7D; yoopies-spid.9fbd=a3f4cea4-5e2b-4175-bf38-cec2c7f8b218.1743408872.1.1743409005..485005b4-209d-4953-a463-c3c5862d7ba3..b761f7ce-7302-4eca-b97e-e2e0ef52c250.1743408872179.8; _ga_SREN84X3EX=GS1.1.1743408872.1.1.1743409460.60.0.0; PHPSESSID=p5nggnq8d9fqetlel6i2abl57s; device_view=full'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#     "data": {
#         "ads": {
#             "count": 9114,
#             "countPages": 912,
#             "perPage": 10,
#             "currentPage": 1,
#             "distance": 50,
#             "pageInfo": {
#                 "hasNextPage": true,
#                 "hasPreviousPage": false,
#                 "endCursor": "eW9vcGllc19jdXJzb3I6MTA=",
#                 "__typename": "PageInfo"
#             },
#             "edges": [
#                 {
#                     "node": {
#                         "score": null,
#                         "ad": {
#                             "id": 2325646,
#                             "slug": {
#                                 "title": "garde-d-enfants-partir-03",
#                                 "city": "paris",
#                                 "__typename": "Slug"
#                             },
#                             "title": "Garde d\u0027enfants \u00e0 partir de 03 ans",
# ...

# %%
from ProfilesScraper import scrape

scrape(care_type="childcare", sub_type="babysitting", )
# Out:
# Running YoopiesScraper example...
# [2025-04-05 19:42:42] INFO - Logger initialized. Log file: data\raw\yoopies\75000\childcare\babysitting\scrape_babysitting.log
# [2025-04-05 19:42:42] INFO - Initialized directory structure and metadata stubs up to: data\raw\yoopies\75000\childcare\babysitting
# [2025-04-05 19:42:42] INFO - --- Starting Yoopies Scrape Run ---
# [2025-04-05 19:42:42] INFO - Run ID: 952a4dd6-55ba-4e07-91ca-bad98adcbd3f
# [2025-04-05 19:42:42] INFO - Target: yoopies/75000/childcare/babysitting
# [2025-04-05 19:42:42] INFO - Starting profile fetch for 75000 (Paris) - childcare/babysitting. Run ID: 952a4dd6-55ba-4e07-91ca-bad98adcbd3f
# [2025-04-05 19:42:42] INFO - Requesting page 0...
# [2025-04-05 19:43:05] INFO - Total profiles expected for this search: 26231
# [2025-04-05 19:43:05] INFO - Saved page 0 (100 profiles) to data\raw\yoopies\75000\childcare\babysitting\page_0.json
# [2025-04-05 19:43:06] INFO - Requesting page 1...
# ...

# %%
from ProfilesScraper import scrape

scrape(care_type="seniorcare", sub_type="carer")

# %%
from ProfilesScraper import scrape

scrape(care_type="housekeeping", sub_type="housekeeper")
